# %%
from sentee_module import *

# %%
pd.read_csv('1.2 Absenteeism_data.csv')
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
model = absenteeism_model('model', 'scalar')
# Out:
# C:\Users\13kau\Anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\13kau\Anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
model.load_and_clean_data('1.2 Absenteeism_data.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-65dac807713d> in <module>
# ----> 1 model.load_and_clean_data('1.2 Absenteeism_data.csv')
#
# ~\Desktop\Data\sentee_module.py in load_and_clean_data(self, data_file)
#      97         self.preprocessed_data = df.copy()
#      98
# ---> 99         self.data = self.scaler.transform(df)
#     100
#     101     def predicted_probablity(self):
#
# ~\Desktop\Data\sentee_module.py in transform(self, X, y, copy)
#      32
#      33         init_col_order = X.columns
# ---> 34         X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)
#      35         X_not_scaled = X.loc[:,~X.columns.isin(self.columns)]
#      36         return pd.concat([X_not_scaled, X_scaled], axis=1)[init_col_order]
#
# ~\Anaconda3\envs\py3-TF2.0\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...
